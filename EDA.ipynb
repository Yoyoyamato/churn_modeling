# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## plot size
plt.rcParams.update({'figure.figsize':(15,6)})
plt.rcParams.update({'font.size':18})

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
### EDA report on CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Exited

# %%
df['Exited'].value_counts().head(2).plot(kind='bar', rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### CreditScore

# %%
sns.distplot(df['CreditScore'],bins=50, kde=False)
# Out:
# /Users/yamato0615/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CreditScore'>

# %%
sns.histplot(x="CreditScore",hue="Exited",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='Count'>

# %%
Cat_Age=pd.cut(x=df["CreditScore"],bins=5)
sns.countplot(x=Cat_Age,hue=df["Exited"])
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='count'>

# %% [markdown]
# ### Geography

# %%
df['Geography'].value_counts().head(20).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="Geography",hue="Exited",data=df)
# Out:
# <AxesSubplot:xlabel='Geography', ylabel='count'>

# %% [markdown]
# ### Gender

# %%
df['Gender'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="Gender",hue="Exited",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Age

# %%
sns.distplot(df['Age'],bins=30, kde=False)
# Out:
# /Users/yamato0615/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.histplot(x="Age",hue="Exited",data=df,palette="autumn")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### Tenure

# %%
sns.distplot(df['Tenure'],bins=11, kde=False)
# Out:
# /Users/yamato0615/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tenure'>

# %% [markdown]
# ### Balance

# %%
sns.distplot(df['Balance'],bins=20, kde=False)
# Out:
# <AxesSubplot:xlabel='Balance'>

# %%
sns.boxplot(y="Balance",x="Exited",data=df)
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='Balance'>

# %% [markdown]
# ### NumOfProducts

# %%
sns.distplot(df['NumOfProducts'],bins=4, kde=False)
# Out:
# /Users/yamato0615/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NumOfProducts'>

# %%
sns.countplot(x="NumOfProducts",hue="Exited",data=df)
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='count'>

# %% [markdown]
# ### HasCrCard

# %%
df['HasCrCard'].value_counts().head(2).plot(kind='bar', rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### IsActiveMember

# %%
df['IsActiveMember'].value_counts().head(2).plot(kind='bar', rot=0)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="IsActiveMember",hue="Exited",data=df)
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %% [markdown]
# ### EstimatedSalary

# %%
sns.distplot(df['EstimatedSalary'],bins=60, kde=False)
# Out:
# /Users/yamato0615/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EstimatedSalary'>

# %%
sns.boxplot(y="EstimatedSalary",x="Exited",data=df)
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='EstimatedSalary'>

# %% [markdown]
# ## Data Preprocessing

# %%
## trim the age, so that we focus on customers under 75
## create dummy variables for the geography and gender variables
## create 2 versions of df; with balance KNN imputer & without (leave as it is)
# feature engineering???

# %% [markdown]
# #### Trimming the `Age` variable

# %%
df.Age.min()
# Out:
# 18

# %%
df.Age.max()
# Out:
# 92

# %% [markdown]
# We want to target your customers that is between 18 and 75 years old. We understand that there are customers that is older 75, but in order to make this model focusing on core customers, we will be trimming the Age column by putting a upper boundary.

# %%
df = df[df["Age"]<=75]

# %% [markdown]
# #### Creating dummy variables

# %%
dum = pd.get_dummies(df[['Geography','Gender']],drop_first=True)
dum.head()
# Out:
#    Geography_Germany  Geography_Spain  Gender_Male
# 0                  0                0            0
# 1                  0                1            0
# 2                  0                0            0
# 3                  0                0            0
# 4                  0                1            0

# %%
df['Geography_Germany'] = dum['Geography_Germany']
df['Geography_Spain'] = dum['Geography_Spain']
df['Gender_Male'] = dum['Gender_Male']
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Geography_Germany  Geography_Spain  Gender_Male
# 0        101348.88       1                  0                0            0
# ...

# %% [markdown]
# #### Using KNN Imputer for `Balance` variable
